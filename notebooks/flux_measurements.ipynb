# %%
import os, sys
import numpy as np
from astropy import units, constants
from astropy.io import fits
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
from astropy.table import Table, Column
from scipy.optimize import minimize, curve_fit
from lightkurve.lightcurve import LightCurve
from scipy.signal import find_peaks, gaussian
from scipy.interpolate import interp1d
from lmfit import Model
import lmfit
from lightkurve.lightcurve import LightCurve

from specutils import Spectrum1D, SpectralRegion
from specutils.fitting import find_lines_threshold,fit_lines,estimate_line_parameters
from astropy.modeling import models
from specutils.analysis import centroid, fwhm, equivalent_width, line_flux
from astropy.nddata import NDUncertainty

#from stella.utils import flare_lightcurve

# %load_ext autoreload
# %autoreload 2
sys.path.append('/Users/arcticfox/Documents/GitHub/cos_flares/src/')
from utils import *
from cos_flares import FlaresWithCOS

## PROPOSAL ID 16164
COLOR = 'k'
plt.rcParams['font.size'] = 20
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

plt.rcParams['xtick.major.width'] = 3
plt.rcParams['ytick.major.width'] = 3
plt.rcParams['xtick.major.size']  = 10 #12
plt.rcParams['ytick.major.size']  = 10 #12

plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.minor.size']  = 6
plt.rcParams['ytick.minor.size']  = 6

plt.rcParams['axes.linewidth'] = 3

plt.rcParams['font.size'] = 20
plt.rcParams['text.color'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['axes.edgecolor'] = COLOR
plt.rcParams['figure.facecolor'] = 'none'
plt.rcParams['legend.facecolor'] = 'none'

def load_data(path):
    wavelength, flux, err = load_binned_data(os.path.join(path,'interp_between_1.npy'))

    times = np.load(os.path.join(path,'times.npy'))
    orbits = np.load(os.path.join(path,'orbits.npy'))

    wavelength = np.full(flux.shape, wavelength)
    return wavelength, flux, err, times, orbits

w20, f20, e20, t20, o20 = load_data(path='/Users/arcticfox/Documents/AUMic/30s/reduced')
w30, f30, e30, t30, o30 = load_data(path='/Users/arcticfox/Documents/AUMic/30s/reduced2')

_, flare_orbits, flare_mask = np.load('/Users/arcticfox/Documents/AUMic/flare_mask2.npy',
                                      allow_pickle=True)

parula = np.load('/Users/arcticfox/parula_colors.npy')

distance = (9.72*units.pc).to(units.cm)

# %%
fwc = FlaresWithCOS(wavelength=np.append(w20, w30, axis=0), 
                    flux=np.append(f20, f30, axis=0),
                    flux_err=np.append(e20, e30, axis=0), 
                    time=np.append(t20, t30)-t20[0], 
                    orbit=np.append(o20, o30+5))
fwc.load_line_table(path='/Users/arcticfox/Documents/GitHub/cos_flares/')
fwc.load_lsf_model(fname='/Users/arcticfox/Documents/AUMic/aa_LSFTable_G130M_1222_LP4_cn.dat')

default_mask = fwc.measure_FUV130()

for ion in fwc.line_table['ion']:
    fwc.measure_ew(ion)

# %%
all_med = np.nanmean(fwc.flux,axis=0)
a = all_med > 0
plt.figure(figsize=(14,5))
ions = ['SiII', 'SiIII', 'CIII','NV_1','FeXXI']

label=False
save=False
outname = 'spectrum.png'

if label:
    for i in range(len(ions)):
        plt.vlines(fwc.line_table[fwc.line_table['ion']==ions[i]]['wave_c'],
                   0, 1, color=parula[225], lw=3)
        s = ions[i].split('_')[0]
        plt.text(s=s, x=fwc.line_table[fwc.line_table['ion']==ions[i]]['wave_c']-8,
                 y=1e-17, color='w', rotation=90)
    outname = 'spectrum_labeled.png'

plt.plot(fwc.wavelength[0][a][:-100], all_med[a][:-100], 
         c=parula[60])

plt.ylim(1e-19,1e-12)
plt.xlim(1060,1364)
plt.yscale('log')
plt.xlabel('Wavelength [$\AA$]', fontsize=24)
plt.ylabel('Flux Density [erg $\AA^{-1}$ s$^{-1}$ cm$^{-2}$]', 
                   fontsize=20)
if save:
    plt.savefig('/Users/arcticfox/Documents/AUMic/figures/{}'.format(outname),
                dpi=300, rasterize=True, bbox_inches='tight', transparent=True)

# %%
a = np.nansum(flare_mask,axis=0) == 0
all_med = np.nanmean(fwc.flux[a],axis=0)
flareb = np.nanmean(fwc.flux[flare_mask[1]>0],axis=0)

plt.figure(figsize=(14,5))

label=False
save=False
outname = 'spectrum.png'

q = all_med>0
plt.plot(fwc.wavelength[0][q],
         all_med[q],
         c=parula[60])

q = flareb>0
plt.plot(fwc.wavelength[0][q],
         flareb[q],
         c=parula[160])

plt.ylim(1e-19,1e-12)
plt.xlim(1060,1364)
plt.yscale('log')
plt.xlabel('Wavelength [$\AA$]', fontsize=24)
plt.ylabel('Flux Density [erg $\AA^{-1}$ s$^{-1}$ cm$^{-2}$]', 
                   fontsize=20)

tab1 = Table()
tab1['wavelength_AA'] = fwc.wavelength[0]
tab1['flux_density'] = all_med

tab2 = Table()
tab2['wavelength_AA'] = fwc.wavelength[0]
tab2['flux_density'] = flareb

if save:
    plt.savefig('/Users/arcticfox/Documents/AUMic/figures/{}'.format(outname),
                dpi=300, rasterize=True, bbox_inches='tight', transparent=True)

# %%
tab1.write('/Users/arcticfox/Documents/GitHub/cos_flares/data/quiescent_feinstein.txt',
           format='csv',overwrite=True)
tab2.write('/Users/arcticfox/Documents/GitHub/cos_flares/data/flareB_feinstein.txt',
           format='csv',overwrite=True)

# %% [markdown]
# ## Spectrum figure for paper

# %%
def to_velocity(wave, flux=None, line=None):
    if line != None:
        argmid = np.where(wave>=line)[0][0]
    else:
        argmid = int(len(wave)/2)
        if flux is not None:
            argmid = np.argmin(flux)
    lambda0 = wave[argmid] + 0.0
    rv_m_s = ((wave - lambda0)/lambda0 * 3e8)*units.m/units.s
    rv_km_s = rv_m_s.to(units.km/units.s)
    return rv_km_s, argmid

# %%
lines = Table.read('/Users/arcticfox/Documents/AUMic/aumic_linelist.csv',format='csv')

# %%
# %matplotlib inline
plt.rcParams['font.size']=16
vel_col = np.zeros(len(lines))
wave_obs = np.zeros(len(lines))
scaling = 10**-15

for i in range(len(lines)):
    
    spectrum = Spectrum1D(flux=(med[q]/scaling)*fwc.flux_units-1*fwc.flux_units, 
                          spectral_axis=fwc.wavelength[0][q]*units.AA)
    
    g_init = models.Gaussian1D(amplitude=5*fwc.flux_units, 
                               mean=lines['Wavelength'][i]*units.AA,
                               stddev=0.02*units.AA)
    
    g_fit = fit_lines(spectrum, g_init, window=((lines['Wavelength'][i]-0.1)*units.AA,
                                                (lines['Wavelength'][i]+0.1)*units.AA))
    y_fit = g_fit(fwc.wavelength[0][q]*units.AA)
    
    vel,_ = to_velocity(fwc.wavelength[0][q],line=lines['Wavelength'][i])
    linecenter = np.where(fwc.wavelength[0][q]>=g_fit.mean.value)[0][0]
    
    plt.figure(figsize=(10,3))
    plt.plot(fwc.wavelength[0][q],(med[q]/scaling)-1, 'k')
    plt.plot(fwc.wavelength[0][q], y_fit,'darkorange',lw=3)

    plt.xlim(lines['Wavelength'][i]-1, lines['Wavelength'][i]+1)
    plt.ylim(np.nanmin(y_fit.value), np.nanmax(y_fit.value)+0.5)
    plt.vlines(lines['Wavelength'][i],-1,100,color='k',linestyle='--',lw=3)
    
    plt.title(i)
    
    print(lines['Ion'][i], vel[linecenter].value)
    vel_col[i] = vel[linecenter].value
    wave_obs[i] = g_fit.mean.value
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-73-b39104f70082> in <module>
#       8
#       9     spectrum = Spectrum1D(flux=(med[q]/scaling)*fwc.flux_units-1*fwc.flux_units,
# ---> 10                           spectral_axis=fwc.wavelength[0][q]*units.AA)
#      11
#      12     g_init = models.Gaussian1D(amplitude=5*fwc.flux_units,
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 32768 but corresponding boolean dimension is 9707

# %%
#lines.add_column(Column(vel_col*units.km/units.s,'velocity_offset'))

# %%
np.where(np.abs(vel_col)>=100)[0]
# Out:
# array([  3,  15,  16,  17,  24,  34,  36,  40,  43,  59,  89,  95, 102,
#        111, 113, 119])

# %%
scaling = 10**-15

for i in np.where(np.abs(vel_col)>=100)[0]:
    
    spectrum = Spectrum1D(flux=(med[q]/scaling)*fwc.flux_units-1*fwc.flux_units, 
                          spectral_axis=fwc.wavelength[0][q]*units.AA)
    
    g_init = models.Gaussian1D(amplitude=5*fwc.flux_units, 
                               mean=lines['Wavelength'][i]*units.AA,
                               stddev=0.02*units.AA)
    
    g_fit = fit_lines(spectrum, g_init, window=((lines['Wavelength'][i]-0.05)*units.AA,
                                                (lines['Wavelength'][i]+0.05)*units.AA))
    y_fit = g_fit(fwc.wavelength[0][q]*units.AA)
    
    vel,_ = to_velocity(fwc.wavelength[0][q],line=lines['Wavelength'][i])
    linecenter = np.where(fwc.wavelength[0][q]>=g_fit.mean.value)[0][0]
    
    plt.figure(figsize=(10,3))
    plt.plot(fwc.wavelength[0][q],(med[q]/scaling)-1, 'k')
    plt.plot(fwc.wavelength[0][q], y_fit,'darkorange',lw=3)

    plt.xlim(lines['Wavelength'][i]-1, lines['Wavelength'][i]+1)
    #plt.ylim(np.nanmin(y_fit.value), np.nanmax(y_fit.value)+0.5)
    plt.ylim(-2,10)
    plt.vlines(lines['Wavelength'][i],-1,100,color='k',linestyle='--',lw=3)
    
    plt.title(i)
    
    print(lines['Ion'][i], vel[linecenter].value)
    vel_col[i] = vel[linecenter].value
    wave_obs[i] = g_fit.mean.value
    plt.show()
# Out:
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fe III -1439.7776253977258
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fe III 949.444697821501
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# C I -1184.1996566837206
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# C I -1026.923066651652
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# C I -865.8260154849177
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# C I 361.3525232280915
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# Fe II 3687.995519919222
# ...

# %%
lines.replace_column('velocity_offset',vel_col*units.km/units.s)
lines.replace_column( 'wave_obs',wave_obs*units.AA)

# %%
lines['Wavelength']*=units.AA

# %%
lines.write('/Users/arcticfox/Documents/AUMic/aumic_linelist.csv',format='csv',
             overwrite=True)

# %% [markdown]
# # Full line list

# %%
lines = Table.read('/Users/arcticfox/Documents/AUMic/aumic_linelist.csv',format='csv')

# %%
def which_axis(axes,wavelength,line):
    o1_list = np.arange(0,13900,1,dtype=int).reshape((2,int((13900)/2)))
    o2_list = np.arange(14200,28640,1,dtype=int).reshape((2,int((28640-14200)/2)))
    
    if (line <= wavelength[o1_list[0]][-1]):
        a=axes[0]
    elif ((line > wavelength[o1_list[0]][-1]) and
          ((line < wavelength[o1_list[1]][-1]))):
        a=axes[1]
    elif ((line > wavelength[o1_list[1]][-1]) and
          ((line <= wavelength[o2_list[0]][-1]))):
        a=axes[2]
    else:
        a=axes[3]
    return a

# %%
plt.rcParams['font.size'] = 20

lw=3.5

fig,allaxes = plt.subplots(nrows=4,ncols=1, figsize=(20,24))
mask = np.nansum(flare_mask,axis=0)==0
fig.set_facecolor('w')

axes = allaxes.reshape(-1)
o1_list = np.arange(0,13900,1,dtype=int).reshape((2,int((13900)/2)))
o2_list = np.arange(14200,28640,1,dtype=int).reshape((2,int((28640-14200)/2)))

med = np.nanmean(fwc.flux[mask], axis=0)
med_err = np.sqrt(np.nansum(fwc.flux_err[mask]**2, axis=0))/len(fwc.flux_err[mask])**2
q = (med > 0) 


for i in range(len(lines)):
    a = which_axis(axes, fwc.wavelength[0][q], lines['wave_obs'][i])
    
    if type(lines['Forest'][i])==np.ma.core.MaskedConstant and lines['velocity_offset'][i]<25:
        ind = np.where(fwc.wavelength[0][q]>=lines['wave_obs'][i])[0][0]
        height = med[q][ind]+1e-15
        
        if lines['Ion'][i]=='O I':
            c='#d10a50'
        else:
            c=parula[80]
        
        a.vlines(lines['wave_obs'][i], height,height+height*1.5,
                  color=c,lw=lw)
        
        a.text(s=lines['Ion'][i], 
               y=height+height*2, 
               x=lines['wave_obs'][i]-0.5, 
               rotation=90,
               fontsize=18)
        
c=parula[80]        
for i in np.unique(lines['Forest'])[:-1]:
    templines = lines[(lines['Forest']==i)&(np.abs(lines['velocity_offset'])<30)]
    a = which_axis(axes, fwc.wavelength[0][q], templines['wave_obs'][0])
    
    ind1 = np.where(fwc.wavelength[0][q]>=templines['wave_obs'][0])[0][0]
    ind2 = np.where(fwc.wavelength[0][q]>=templines['wave_obs'][-1])[0][0]
    
    height = np.nanmax(med[q][ind1:ind2])+1e-15
    
    offset=0.8
    if len(np.unique(templines['Ion']))>2:
        names = [e for e in np.unique(templines['Ion']) if e!='?']
        breakup = np.arange(0,len(names),2,dtype=int)
        breakup = np.append(breakup,len(names))
        text=''
        for j in range(len(breakup)-1):
            links = names[breakup[j]:breakup[j+1]]
            text+=', '.join(str(e) for e in links)
            if j < len(breakup)-2:
                text+=',\n'
        if len(breakup)==3:
            offset=1.1
        elif len(breakup)==2:
            offset=0.6
        elif len(breakup)==4:
            offset=1.7
        else:
            offset=3.4
    else:
        text=', '.join(str(e) for e in np.unique(templines['Ion']) if e!='?')
        offset=0.5
    
    if text == 'He II, N II':
        text = 'He II,\nN II'
        offset=1.1
    
    if text=='S I, Si II,\nSi III':
        #height=height-height*1.5
        yt=height+height*0.4
        y1,y2,y3=height-height*0.9,height-height*0.6,height
    else:
        yt=height+height*3.5
        y1,y2,y3=height,height+height*1.5,height+height*2.5
        
    a.vlines(templines['wave_obs'][0], y1,y2,
                  color=c,lw=lw)
    a.vlines(np.nanmedian([templines['wave_obs'][0],templines['wave_obs'][-1]]), 
             y2, y3,
             color=c,lw=lw)
    a.vlines(templines['wave_obs'][-1], y1,y2,
                  color=parula[80],lw=lw)
    a.hlines(y2, templines['wave_obs'][0]-0.1, templines['wave_obs'][-1]+0.1,
             color=c,lw=lw)

    a.text(s=text,
          y=yt,
          x=np.nanmedian([templines['wave_obs'][0],templines['wave_obs'][-1]])-offset,
          rotation=90,
          fontsize=18)

x=0
for i in range(len(axes)):
    if i<2:
        axes[i].plot(fwc.wavelength[0][q][o1_list[x]], 
                     med[q][o1_list[x]], 'k')
        axes[i].set_xlim(fwc.wavelength[0][q][o1_list[x]][0]-0.05,
                         fwc.wavelength[0][q][o1_list[x]][-1]+0.05)
    else:
        axes[i].plot(fwc.wavelength[0][q][o2_list[x]], 
                     med[q][o2_list[x]], 'k')
        axes[i].set_xlim(fwc.wavelength[0][q][o2_list[x]][0]-0.05,
                         fwc.wavelength[0][q][o2_list[x]][-1]+0.05)
    x += 1
    
    if x > 1:
        x=0
    if i ==1 or i==2:
        axes[i].set_ylim(10**-15.5,10**-11.5)
    elif i==0:
        axes[i].set_ylim(10**-17,10**-11.5)
    else:
        axes[i].set_ylim(10**-15.5,10**-11)
    axes[i].set_yscale('log')


axes[-1].set_xlabel('Wavelength [$\AA$]', fontsize=30)
axes[2].set_ylabel('Flux Density [erg $\AA^{-1}$ s$^{-1}$ cm$^{-2}$]', 
                   fontsize=30,
                   y=1.1)
#ax1.set_title('Median out-of-flare Spectra for AU Mic', fontsize=26)
for a in axes:
    a.set_rasterized(True)

#plt.savefig('/Users/arcticfox/Documents/AUMic/paper/alllines.pdf', 
#            rasterize=True,
#            dpi=300, bbox_inches='tight')#, transparent=True)

# %%
paper_table=Table()
paper_table.add_column(Column(lines['Ion'], 'Ion'))
paper_table.add_column(Column(lines['Wavelength'], 'wave_rest'))
paper_table.add_column(Column(lines['wave_obs'], 'wave_obs'))
paper_table=paper_table[np.abs(lines['velocity_offset'])<25]

# %% [markdown]
# ## Measure line fluxes

# %%
def gaussian(x, mu, std, offset, f):
    """ A gaussian model. """
    exp = -0.5 * (x-mu)**2 / std**2
    denom = std * np.sqrt(np.pi * 2.0)
    g = f / denom * np.exp(exp)
    return g+offset

# %%
def initialize_model(pars, n,i,which='wavelength', mulim=25):
    if which == 'wavelength':
        pars['g{}_mu'.format(n)].set(value=paper_table['wave_obs'][i], 
                       min=paper_table['wave_obs'][i]-0.3, max=paper_table['wave_obs'][i]+0.3)
        pars['g{}_std'.format(n)].set(value=stddev, min=0.001, max=0.2)
        pars['g{}_f'.format(n)].set(value=1, min=0.1, max=200)
        pars['g{}_offset'.format(n)].set(value=-1, min=-2, max=0)
    else:
        pars['g{}_mu'.format(n)].set(value=0, min=-mulim, max=mulim)
        pars['g{}_std'.format(n)].set(value=10, min=0.001, max=100)
        pars['g{}_f'.format(n)].set(value=1, min=0.1, max=5000)
        pars['g{}_offset'.format(n)].set(value=-1, min=-2, max=0)
    return pars

# %%
spectrum = Spectrum1D(flux=f[qq]*fwc.flux_units,
                      uncertainty=ferr[qq]/scaling,
                      spectral_axis=fwc.wavelength[0][q][qq]*units.AA,
                      velocity_convention="optical",
                      rest_value=paper_table['wave_obs'][i]*units.AA)
g_init = models.Gaussian1D(amplitude=5*fwc.flux_units, 
                           mean=paper_table['wave_obs'][i]*units.AA,
                           stddev=0.02*units.AA)
g_fit = fit_lines(spectrum, g_init, window=((paper_table['wave_obs'][i]-0.05)*units.AA,
                                            (paper_table['wave_obs'][i]+0.05)*units.AA))
mean, stddev = g_fit.mean.value, g_fit.stddev.value
#y_fit = g_fit(fwc.wavelength[0][q][qq]*units.AA)

# %%
scaling = 10**-15
f = ((med[q]/scaling)/np.nanmedian(med[q]/scaling)-1)
ferr = med_err[q]/scaling

area_array = np.zeros(len(paper_table))
fwhm_array = np.zeros(len(paper_table))
chsq_array = np.zeros(len(paper_table))

for i in range(20,50):#len(paper_table)):
    
    vel, _ = to_velocity(fwc.wavelength[0][q], line=paper_table['wave_obs'][i])
    vel = vel.value
    
    qq = np.where((vel>=-100) & (vel<=100))[0]
    vel = vel[qq]
      
    counter = 1
    
    others = np.delete(np.arange(0,len(paper_table),1,dtype=int),i)
    if ( (np.nanmin(np.abs(paper_table['wave_obs'][i]-paper_table['wave_obs'][others]))<0.5)):
        print('close encounter')
        inds = np.where((np.abs(paper_table['wave_obs'][i]-paper_table['wave_obs'][others])<0.5) &
                        (np.abs(paper_table['wave_obs'][i]-paper_table['wave_obs'][others])>0))[0]
        real_inds = np.append(i, others[inds])
        gmodel = Model(gaussian, prefix='g{}_'.format(0))
        for n in range(len(inds)):
            counter += 1
            gmodel += Model(gaussian, prefix='g{}_'.format(n+1))
            
        pars = gmodel.make_params()
        pars += initialize_model(pars, 0, i,which='velocity',mulim=100)
        
        for n in range(len(inds)):
            pars += initialize_model(pars, n+1, inds[n],which='velocity',mulim=100)
    
    else:
        gmodel = Model(gaussian, prefix='g{}_'.format(0))
        pars = gmodel.make_params()
        pars = initialize_model(pars, 0, i,which='velocity')
    
    init = gmodel.eval(pars, x=vel)
    out = gmodel.fit(f[qq], pars,
                     x=vel,
                     weights=1/ferr[qq],
                     verbose=True,
                     max_nfev=3000)
    mini = out.minimize(max_nfev=3000)
    
    fh = 2*np.sqrt(2*np.log(2))*mini.params['g0_std'].value
    area = np.trapz(out.best_fit*scaling*fwc.flux_units,
                    x=fwc.wavelength[0][q][qq]*units.AA)
    print(counter)
    if counter > 1:
        for c in range(counter):
            g = gaussian(vel, 
                 mini.params['g{}_mu'.format(c)].value,
                 mini.params['g{}_std'.format(c)].value, 
                 mini.params['g{}_offset'.format(c)].value,
                 mini.params['g{}_f'.format(c)].value)
            fh = 2*np.sqrt(2*np.log(2))*mini.params['g{}_std'.format(c)].value
            area = np.trapz(g*scaling*fwc.flux_units,
                        x=fwc.wavelength[0][q][qq]*units.AA)
            fwhm_array[real_inds[c]] = fh
            area_array[real_inds[c]] = area.value
            chsq_array[real_inds[c]] = mini.chisqr
        
    else:
        area_array[i] = area.value
        fwhm_array[i] = fh
        chsq_array[i] = mini.chisqr

    plt.plot(vel, f[qq])
    plt.plot(vel, out.best_fit, 'k')
    #plt.plot(spectrum.spectral_axis,y_fit)
    #plt.ylim(-2,np.nanmax(y_fit.value)+3)

    plt.title(mini.chisqr)
    #plt.title(np.trapz(out.best_fit*fwc.flux_units,x=fwc.wavelength[0][q][qq]*units.AA))
    plt.show()
linefluxes*=units.erg/units.s/units.cm**2
# Out:
# 1
# close encounter
# 2
# close encounter
# 3
# close encounter
# 3
# close encounter
# 3
# close encounter
# 3
# close encounter
# 2
# 1
# 1
# 1
# close encounter
# 2
# close encounter
# 2
# close encounter
# 2
# close encounter
# 2
# 1
# 1
# close encounter
# 2
# close encounter
# 3
# close encounter
# 3
# close encounter
# 2
# close encounter
# 3
# close encounter
# 4
# close encounter
# 4
# close encounter
# 3
# 1
# close encounter
# 2
# close encounter
# 2
# close encounter
# 2
# close encounter
# 2
# close encounter
# 3

# %% [markdown]
# ## Fitting a BB spectrum

# %%
from lmfit import Model

COLOR = 'k'
plt.rcParams['font.size'] = 20
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR

plt.rcParams['xtick.major.width'] = 3
plt.rcParams['ytick.major.width'] = 3
plt.rcParams['xtick.major.size']  = 10 #12
plt.rcParams['ytick.major.size']  = 10 #12

plt.rcParams['xtick.minor.width'] = 1
plt.rcParams['ytick.minor.width'] = 1
plt.rcParams['xtick.minor.size']  = 6
plt.rcParams['ytick.minor.size']  = 6

plt.rcParams['axes.linewidth'] = 3

plt.rcParams['font.size'] = 20
plt.rcParams['text.color'] = COLOR
plt.rcParams['xtick.color'] = COLOR
plt.rcParams['ytick.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['axes.spines.top'] = True
plt.rcParams['axes.spines.right'] = True
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['axes.edgecolor'] = COLOR
plt.rcParams['figure.facecolor'] = 'none'
plt.rcParams['legend.facecolor'] = 'none'

fwc.identify_continuum()
flux_units = fwc.flux_units

# %%
plt.figure(figsize=(14,4))
mask = np.nansum(flare_mask,axis=0)==0

med = np.nanmean(fwc.flux[mask], axis=0)
med_err = np.sqrt(np.nansum(fwc.flux_err[mask]**2, axis=0))/len(fwc.flux_err[mask])**2
q = (med > 0) 
c = (med>0) & (fwc.continuum_mask[0]==0)
plt.errorbar(fwc.wavelength[0][q], 
             med[q], 
             yerr=med_err[q], marker='o', linestyle='')
#plt.plot(fwc.wavelength[0][c], med[c],'.', label='Continuum', c=parula[30])

plt.yscale('log')
plt.xlabel('Wavelength [$\AA$]')
plt.ylabel('Flux')

#plt.legend()
#plt.savefig('/Users/arcticfox/Documents/AUMic/figures/continuum_region.png', rasterize=True,
#            dpi=300, bbox_inches='tight')#, transparent=True)
# Out:
# Text(0, 0.5, 'Flux')

# %%
np.save('/Users/arcticfox/Documents/AUMic/spectrum_data.npy',
        [fwc.wavelength[0][q], np.diff(fwc.wavelength[0][q]),
         med[q], med_err[q]])
# Out:
# //anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py:528: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %%
def bb(x, T, scaling):
    global flux_units
    T *= units.K
    x *= units.AA
    frac = 2.0 * constants.h * constants.c**2 / x**5
    exp = (constants.h * constants.c) / (x * constants.k_B * T)
    func =  frac * 1.0/(np.exp(exp) - 1.0)
    func = func.to(flux_units)
    return np.log10(func.value)*scaling

def photon_wavelength(E):
    w =  (constants.h * constants.c)/E
    return w.to(units.AA)

def L_to_flux(L, distance):
    F = L / (4 * np.pi * distance**2)
    return F.to(units.erg/units.s/units.cm**2)

def bremsstrahlung(x, T):#, offset):
    x /= units.s
    ne = 300 / units.m**3
    T *= units.K
    c = 10 * units.m**5 * (units.K)**(0.5) / units.s**4 * units.kg
    const = c * 4 * np.pi * ne**2 * T**(-0.5)
    frac =  - constants.h / (constants.k_B * T)
    expo = (constants.h * x) / (constants.k_B * T)
    
    brem = const * frac * np.exp(-expo)
    brem = (brem.to(units.W/units.m**3)).value
    brem = np.log10(brem - np.nanmin(brem))
    return brem #+ offset

# %%
wavelength = np.linspace(1100, 1400, 100)*units.AA
freq = (constants.c/wavelength).to(units.s**(-1.0))

x=0
plt.figure(figsize=(10,6))
for i in np.arange(5,7,0.2):
    b = bremsstrahlung(freq.value, 10**i)
    plt.plot(wavelength[:-1], b[:-1]/np.abs(np.nanmedian(b[:-1])), lw=3,c=parula[x],
             label=np.round(i,2))
    x+=25
#plt.xlim(1000,1200)
#plt.ylim(1.6,2.1)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, ncol=2, borderaxespad=0.)
#plt.yscale('log')
# Out:
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/1749072012.py:30: RuntimeWarning: divide by zero encountered in log10
#   brem = np.log10(brem - np.nanmin(brem))
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/1749072012.py:30: RuntimeWarning: divide by zero encountered in log10
#   brem = np.log10(brem - np.nanmin(brem))
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/1749072012.py:30: RuntimeWarning: divide by zero encountered in log10
#   brem = np.log10(brem - np.nanmin(brem))
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/1749072012.py:30: RuntimeWarning: divide by zero encountered in log10
#   brem = np.log10(brem - np.nanmin(brem))
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/1749072012.py:30: RuntimeWarning: divide by zero encountered in log10
#   brem = np.log10(brem - np.nanmin(brem))
# ...

# %% [markdown]
# cutoff is approximately $h\mu=kT$

# %%
mu_cutoff = (constants.k_B * (10**6*units.K))/constants.h
(constants.c/mu_cutoff).to(units.AA)
# Out:
# <Quantity 143.87768775 Angstrom>

# %%
(constants.c/(2.08*10**10 * 10**5)/units.Hz).to(units.AA)
# Out:
# <Quantity 1441.30989423 Angstrom>

# %% [markdown]
# ### Fitting a blackbody to the data routine

# %%
def fit_bb(x, y, yerr):
    
    model = Model(bb)
    params = model.make_params()
    params['T'].set(value=10000, min=3000, max=50000)
    params['scaling'].set(value=-2, min=-200, max=100)
    
    result = model.fit(y,
                       params,
                       x=x,
                       weights=1.0/yerr,
                       max_nfev=3000)
    minimize = result.minimize(max_nfev=3000)
    
    bestfit= minimize.params['T'].value + 0.0
    stderr = minimize.params['T'].stderr + 0.0
    
    sfit = minimize.params['scaling'].value + 0.0
    serr = minimize.params['scaling'].stderr + 0.0
    
    upp1 = Model(bb)
    params_upp1 = upp1.make_params()
    params_upp1['T'].set(bestfit+stderr)
    params_upp1['scaling'].set(sfit)#+3*serr)
    
    low1 = Model(bb)
    params_low1 = upp1.make_params()
    params_low1['T'].set(bestfit-stderr)
    params_low1['scaling'].set(sfit)#-3*serr)
    
    return result, low1, params_low1, upp1, params_upp1, bestfit, stderr

# %% [markdown]
# ### Fitting thermal bremstrahlung to the profile routine

# %%
def fit_brem(x, y, yerr):
    
    model = Model(bremsstrahlung)
    params = model.make_params()

    params['T'].set(value=10**6, min=10**3, max=10**8)

    
    f = (constants.c/(x*units.AA)).to(1.0/units.s)
    
    result = model.fit(y,
                       params,
                       x=f.value,
                       weights=1.0/yerr,
                       max_nfev=3000,
                       nan_policy='omit')
    minimize = result.minimize(max_nfev=3000)
    
    bestfit= minimize.params['T'].value + 0.0
    stderr = minimize.params['T'].stderr + 0.0
    
    newx = np.linspace(x[0], x[-1], 100) * units.AA
    f = (constants.c/newx).to(1.0/units.s)
    fit = bremsstrahlung(f.value,  bestfit)
    
    return result, fit, newx, bestfit, stderr, #sfit

# %%
ion_colors = np.append('#878482', parula[np.linspace(0,200,5,dtype=int)])

fig, axes = plt.subplots(nrows=6, ncols=1,figsize=(14,24), sharex=True)
laxes = axes.reshape(-1)


letters=['Quiescent', 'B', 'D', 'H', 'I', 'K']

for j,i in enumerate([-100, 2,4,-4,-3,-1]):
    
    if i > -5:
        qfm = np.where(flare_mask[i]!=0)[0]
    else:
        qfm = np.where(np.nansum(flare_mask,axis=0)==0)[0]
        
    med = np.nanmean(fwc.flux[qfm], axis=0)#/len(qfm)
    std = np.log10(np.sqrt(np.nansum(fwc.flux_err[qfm]**2, axis=0)))/len(qfm)
    #std = np.sqrt(np.nansum(fwc.flux_err[qfm]**2, axis=0))
    
    cmask = np.nanmedian(fwc.continuum_mask[qfm],axis=0) == 0
    
    q = (med[cmask] > 0)# & (std[cmask]>0)
    
    binned = LightCurve(time=fwc.wavelength[qfm[0]][cmask][q], 
                        flux=np.log10(med[cmask][q]),
                        flux_err=std[cmask][q]).bin(time_bin_size=1).remove_nans()

    result, low1, params_low1, upp1, params_upp1, bestfit, stderr = fit_bb(x=binned.time.value,
                                                                           y=binned.flux.value,
                                                                           yerr=binned.flux_err.value)
    
    label='log(T) = {}'.format(np.round(np.log10(bfit_best),2))
    
    laxes[j].errorbar(binned.time.value, 
                      binned.flux.value, 
                      binned.flux_err.value,
                      marker='o', linestyle='', color='k', zorder=2)
    
    
    if i > -5:
        short = binned.time.value <= 1105
        brem_result,bfit,bfit_x,bfit_best,bfit_std = fit_brem(x=binned.time.value[short],
                                                              y=binned.flux.value[short],
                                                              yerr=binned.flux_err.value[short])
        bfitlow = bremsstrahlung(((constants.c/bfit_x).to(1.0/units.s)).value, 
                             bfit_best-bfit_std)#, bfit_off)
        
        u = bfit_x.value < 1100
        laxes[j].plot(bfit_x[u], bfit[u], lw=4, 
                      linestyle='--', zorder=1, color=ion_colors[j],
                      label=label)

    #laxes[j].plot(bfit_x, bfitlow+4, lw=3, zorder=1, color='k')
    #laxes[j].fill_between(bfit_x,
    #                      bfitlow,
    #                      bfitupp,
    #                      color=ion_colors[j],
    #                      alpha=0.4, lw=0)
    
    label='{} +/- {} K'.format(int(np.round(bestfit,0)), int(np.round(stderr,0)))
    
    laxes[j].plot(binned.time.value, result.best_fit, lw=4, 
                  color=ion_colors[j],zorder=1,label=label)
    
    #laxes[j].fill_between(binned.time.value, 
    #                      low1.eval(x=binned.time.value, params=params_low1),
    #                      upp1.eval(x=binned.time.value, params=params_upp1), 
    #                      color=ion_colors[j],
    #                      alpha=0.4, lw=0)
    laxes[j].legend()
    
    ax2 = laxes[j].twinx()
    if i > -5:
        ax2.set_ylabel('Flare {}'.format(letters[j]), fontsize=22)
    else:
        ax2.set_ylabel(letters[j], fontsize=22)
        
    ax2.set_yticks([])
    
    if j == 2:
        laxes[j].set_ylabel('log$_{10}$(Flux Density [erg s$^{-1}$ cm$^{-2}$  $\AA^{-1}$])',
                            fontsize=22)
    if j == 5:
        laxes[j].set_xlabel('Wavelength [$\AA$]', fontsize=22)
    laxes[j].set_rasterized(True)
    
plt.subplots_adjust(hspace=0)
#plt.savefig('/Users/arcticfox/Documents/AUMic/figures/bbs.png',
#            dpi=250, rasterize=True, bbox_inches='tight', transparent=True)

plt.savefig('/Users/arcticfox/Documents/AUMic/paper/bbs.pdf',
            rasterize=True, dpi=300, bbox_inches='tight')
# Out:
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/1749072012.py:30: RuntimeWarning: divide by zero encountered in log10
#   brem = np.log10(brem - np.nanmin(brem))
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/1749072012.py:30: RuntimeWarning: divide by zero encountered in log10
#   brem = np.log10(brem - np.nanmin(brem))
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/1749072012.py:30: RuntimeWarning: divide by zero encountered in log10
#   brem = np.log10(brem - np.nanmin(brem))
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/1749072012.py:30: RuntimeWarning: divide by zero encountered in log10
#   brem = np.log10(brem - np.nanmin(brem))
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/1749072012.py:30: RuntimeWarning: divide by zero encountered in log10
#   brem = np.log10(brem - np.nanmin(brem))
# ...

# %% [markdown]
# ## Combining with FUSE

# %%
redfield = Table.read('/Users/arcticfox/Documents/AUMic/redfield.txt',format='csv')
redfield['flux'] *= 10**-13
redfield['y_low'] *= 10**-13
redfield['y_upp'] *= 10**-13

for ty in np.unique(redfield['type']):
    subtab = redfield[redfield['type']==ty]
    plt.errorbar(subtab['wavelength'], subtab['flux'],
                 yerr=[(subtab['flux']-subtab['y_low']),
                       (subtab['y_upp']-subtab['flux'])],
                 linestyle='',
                 marker='o')
plt.ylim(0,0.3*10**-13)
# Out:
# (0.0, 3e-14)

# %%
fwc.identify_continuum()

# %%
b1 = np.linspace(1075,1150,5)
b2 = np.linspace(1075+np.nanmedian(np.diff(b1)),1150+np.nanmedian(np.diff(b1)),5)

np.vstack([b1,b2]).T
# Out:
# array([[1075.  , 1093.75],
#        [1093.75, 1112.5 ],
#        [1112.5 , 1131.25],
#        [1131.25, 1150.  ],
#        [1150.  , 1168.75]])

# %%
plt.figure(figsize=(14,8))

# [2,-4,-3,-2,-1]

masks = [np.nansum(flare_mask,axis=0)==0,
             flare_mask[1]>0,
             np.nansum(flare_mask[np.arange(-4,0,1)],axis=0)>0]
b1 = np.linspace(1066,1115,5)
b2 = np.linspace(1066+np.nanmedian(np.diff(b1)),1115+np.nanmedian(np.diff(b1)),5)
blue_mask = np.vstack([b1,b2]).T
labels = ['cont', 'visit 1 orbit 3', 'visit 2 orbit 5']
cont_lc = np.zeros((3,len(blue_mask),3))


x = 100
for j,m in enumerate(masks):

    cont = np.nanmean(flux[m], axis=0)

    q = (cont > 0) 
    c = (cont>0) & (fwc.continuum_mask[0]==0)

    plt.plot(fwc.wavelength[0][q], cont[q], parula[x])
    plt.plot(fwc.wavelength[0][c], cont[c],'.', label='Continuum', c=parula[30])

    #####
    med = np.nanmean(flux[m], axis=0)[c]
    med_err = np.sqrt(np.nansum(fwc.flux_err[m]**2,axis=0)[c])/len(mask)

    q = (med > 0) 

    for i, bmask in enumerate(blue_mask):

        cnew = ((fwc.wavelength[0][c]>=blue_mask[i][0]) & 
                (fwc.wavelength[0][c]<=blue_mask[i][1]) & (med>0))
        
        fsum = np.trapz(med[cnew]*fwc.flux_units, x=fwc.wavelength[0][c][cnew]*units.AA)
        
        esum = np.sqrt(np.nansum(med_err[cnew]**2)/len(c))
        medw = np.nanmedian(fwc.wavelength[0][c][cnew])
        
        if i == 0:
            plt.errorbar(medw,
                         fsum.value, #yerr=esum,
                         color=parula[x], marker='o', linestyle='', label=labels[j],
                         markeredgecolor='k')
        else:
            plt.errorbar(medw, fsum.value, #yerr=esum,
                         color=parula[x], marker='o', linestyle='', 
                         markeredgecolor='k')
        cont_lc[j][i] = [medw,fsum.value,esum]

    x += 50


    #plt.yscale('log')
    plt.xlabel('Wavelength [$\AA$]')
    plt.ylabel('Flux')
    plt.xlim(1000,1180)
    plt.ylim(1e-18,4e-13)

    plt.legend()
    #plt.savefig('/Users/arcticfox/Documents/AUMic/figures/continuum_region.png', rasterize=True,
    #            dpi=300, bbox_inches='tight')#, transparent=True)
# Out:
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/3318893385.py:18: RuntimeWarning: Mean of empty slice
#   cont = np.nanmean(flux[m], axis=0)
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/3318893385.py:27: RuntimeWarning: Mean of empty slice
#   med = np.nanmean(flux[m], axis=0)[c]
# /Users/arcticfox/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1216: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/3318893385.py:18: RuntimeWarning: Mean of empty slice
#   cont = np.nanmean(flux[m], axis=0)
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/3318893385.py:27: RuntimeWarning: Mean of empty slice
#   med = np.nanmean(flux[m], axis=0)[c]
# /Users/arcticfox/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1216: RuntimeWarning: Mean of empty slice
# ...

# %%
fig = plt.figure(figsize=(10,6))
fig.set_facecolor('w')
markers = ['o', '^', 's']
ty = np.unique(redfield['type'])
x = 30

labels = ['Continuum', 'Flare B', 'Flares I, J, K, L']
labels_red = ['Redfield Flare 1', 'Redfield Flare 2', 'Redfield Continuum']
cc = [parula[60], parula[160], parula[225]]
if COLOR == 'k':
    cc_red = ['#d9d4d1', '#878482', '#363534']
else:
    cc_red = [ 'w','#d9d4d1', '#878482']

for i in range(len(cont_lc)):
    #if i > 0:
    #   scale=6*10**-13
    #else:
    scale=8*10**-13
    plt.errorbar(cont_lc[i][:,0], 
                 cont_lc[i][:,1]/scale, 
                 yerr=cont_lc[i][:,2]/scale,
                 marker='o', linestyle='', ms=12,
                 color=cc[i], label=labels[i], markeredgecolor='k',zorder=10)
    print(cont_lc[i][:,0][0],cont_lc[i][:,0][-1])
    print(cont_lc[i][:,1][0]/scale - cont_lc[i][:,1][-1]/scale)
    print('--')
    
print('===========')
for i in range(3):
    subtab = redfield[redfield['type']==ty[i]]
    stq = ((subtab['wavelength']>=blue_mask[3][0]) & (subtab['wavelength']<=blue_mask[3][1]))
    t1 = (subtab['flux'][stq]/ cont_lc[i][-2,1])

    plt.errorbar(subtab['wavelength'], 
                 subtab['flux']/10**-13,
                 yerr=[(subtab['flux']-subtab['y_low'])/10**-13, 
                       (subtab['y_upp']-subtab['flux'])/10**-13],
                 linestyle='', color=cc_red[i], ms=12,
                 marker='^', label=labels_red[i], markeredgecolor='k')
    print(subtab['wavelength'][0], subtab['wavelength'][-2])
    print(subtab['flux'][0]/scale - subtab['flux'][-2]/scale)
    print('--')
    x += 80
    
plt.legend(fontsize=16,ncol=1)
plt.ylabel('Flux [$10^{-13}$ erg $\AA^{-1}$ cm$^{-2}$ s$^{-1}$]')
plt.xlabel('Wavelength [$\AA$]')
#plt.savefig('/Users/arcticfox/Documents/AUMic/figures/fuse_lightcurves.png', rasterize=True,
#            dpi=300, bbox_inches='tight', transparent=True)
# Out:
# 1070.031099528831 1120.2271150499532
# -0.0012965082420767701
# --
# 1069.8864563182235 1120.3380081780856
# 0.8771810421330393
# --
# 1069.7466345479697 1120.3524724991464
# 0.7316943854613588
# --
# ...
# 955.076495132128 1104.8678720445064
# 0.0074029126213592256
# --
# 955.076495132128 1104.8678720445064
# 0.003519417475728155
# --
# 955.4937413073714 1104.8678720445064
# -0.00018203883495145762
# --
# Text(0.5, 0, 'Wavelength [$\\AA$]')

# %%
cont_lc[i][:,1]/scale
# Out:
# array([0.81166692, 0.41565517, 0.        , 0.10865328, 0.07997253])

# %%
(cont_lc[0][0][1]-cont_lc[0][-1][1])/cont_lc[0][-1][1]
# Out:
# -0.02050287708540275

# %%
(cont_lc[1][0][1],cont_lc[1][-1][1])
# Out:
# (7.862905992753885e-13, 8.454576556895706e-14)

# %%
(cont_lc[1][0][1]-cont_lc[1][-1][1])/cont_lc[1][-1][1]
# Out:
# 8.300177176041721

# %% [markdown]
# ## Looking at counts

# %%
path1 = '/Users/arcticfox/Documents/AUMic/30s/reduced/a'
path2 = '/Users/arcticfox/Documents/AUMic/30s/reduced2/b'

# %%
def get_counts(path):
    files = np.sort([os.path.join(path, i) for i in os.listdir(path) if
                 i.endswith('x1d.fits')])

    for i,fn in enumerate(files):
        hdu = fits.open(fn)
        #print(hdu[1].data['WAVELENGTH'][1],hdu[1].data['WAVELENGTH'][0])
        wavelength = np.append(hdu[1].data['WAVELENGTH'][1], hdu[1].data['WAVELENGTH'][0])
        c = np.append(hdu[1].data['GCOUNTS'][1], hdu[1].data['GCOUNTS'][0])
        
        if i == 0:
            wave = np.zeros((len(files), len(wavelength)))
            counts = np.zeros((len(files), len(wavelength)))

        wave[i] = wavelength + 0.0
        counts[i] = c + 0.0

        hdu.close()
    wave = np.array(wave)
    counts = np.array(counts)
    sum2 = np.zeros(len(files))
    for i in range(len(wave)):
        sum2[i] = np.nansum(counts[i])

    return wave, counts, sum2

# %%
w1, c1, s1 = get_counts(path1)
w2, c2, s2 = get_counts(path2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/3231760261.py in <module>
#       1 w1, c1, s1 = get_counts(path1)
# ----> 2 w2, c2, s2 = get_counts(path2)
#
# /var/folders/gz/h7_ym7m52dlgq4xpllc1x3m40000gn/T/ipykernel_42454/2237498066.py in get_counts(path)
#       6         hdu = fits.open(fn)
#       7         #print(hdu[1].data['WAVELENGTH'][1],hdu[1].data['WAVELENGTH'][0])
# ----> 8         wavelength = np.append(hdu[1].data['WAVELENGTH'][1], hdu[1].data['WAVELENGTH'][0])
#       9         c = np.append(hdu[1].data['GCOUNTS'][1], hdu[1].data['GCOUNTS'][0])
#      10
#
# ~/opt/anaconda3/lib/python3.9/site-packages/astropy/utils/decorators.py in __get__(self, obj, owner)
#     776                     val = obj_dict.get(self._key, _NotFound)
#     777                     if val is _NotFound:
# ...

# %%
plt.plot(fwc.time[:len(s1)], s1)
plt.plot(fwc.time[:len(s1)],s2)

# %%
fwc.line_table[fwc.line_table['ion']=='CIII']

# %%
main_ions = ['SiII', 'SiIII', 'CIII', 'NV_1', 'FeXXI']

fig, (ax1,ax2) = plt.subplots(ncols=1,nrows=2,figsize=(10,10))
fig.set_facecolor('w')

for i in range(2):
    for n,ion in enumerate(main_ions):
        v, _ = fwc.to_velocity(wave=w1[0], 
                               mid=fwc.line_table[fwc.line_table['ion']==ion]['wave_c'][0])
        vmask = ( (v.value >= fwc.line_table[fwc.line_table['ion']==ion]['vmin'][0]) & 
                  (v.value <= fwc.line_table[fwc.line_table['ion']==ion]['vmax'][0]))

        args = np.where(vmask==True)[0]
        
        if i == 0:
            key_counts = np.nansum(c1[:,args],axis=1)
            cont_args = np.where((np.nansum(flare_mask[:,fwc.orbit<5],axis=0)==0) & 
                             (key_counts>0))[0]
            ax1.plot(fwc.time[fwc.orbit<5], 
                          key_counts/np.nanmedian(key_counts[cont_args]), marker='o',
                     label=ion, c=ion_colors[n])
            ax1.set_xlim(11000,13500)
            ax1.set_ylabel('Counts')
        else:
            key_counts = np.nansum(c2[:,args],axis=1)
            cont_args = np.where((np.nansum(flare_mask[:,fwc.orbit>4],axis=0)==0) & 
                             (key_counts>0))[0]
            ax2.plot(fwc.time[fwc.orbit>4], 
                          key_counts/np.nanmedian(key_counts[cont_args]), 
                     marker='o', c=ion_colors[n])

            ax2.set_xlim(fwc.time[fwc.orbit==9][0].value, 
                              fwc.time[fwc.orbit==9][-1].value)
            ax2.set_ylabel('Counts')
            ax2.set_xlabel('Time - T$_0$ [s]')
ax1.legend(ncol=2)
#plt.savefig('/Users/arcticfox/Documents/AUMic/figures/flare_in_counts.png', rasterize=True,
#            dpi=300, bbox_inches='tight')#, transparent=True)
